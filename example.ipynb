# %% [markdown]
# <a href="https://colab.research.google.com/github/kayana404/strukturData/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 5 nama mahasiswa

# %%
mahasiswa = ["Andi", "Budi", "Citra", "Dewi", "Eko"]
print("List mahasiswa tergoblok: ")
print(mahasiswa)
# Out:
# List mahasiswa tergoblok:
# ['Andi', 'Budi', 'Citra', 'Dewi', 'Eko']

# %% [markdown]
# tambahkan 1 Nama baru dengan append

# %%
mahasiswa.append ("nigga")
print("setelah ditambahkan nama baru")
print(mahasiswa)
# Out:
# setelah ditambahkan nama baru
# ['Andi', 'Budi', 'Citra', 'Dewi', 'Eko', 'nigga', 'nigga']

# %%
mahasiswa.remove ("Budi")
print("setelah remove nama Budi")
print(mahasiswa)
# Out:
# setelah remove nama Budi
# ['Andi', 'Citra', 'Dewi', 'Eko', 'nigga', 'nigga']
