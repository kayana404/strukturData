# %% [markdown]
# <a href="https://colab.research.google.com/github/kayana404/strukturData/blob/main/tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nilai_mahasiswa = []
for i in range(10):
  n = int(input(f"masukkan nilai mahasiswa ke-{i+1} :"))
  nilai_mahasiswa.append(n)
# Out:
# masukkan nilai mahasiswa ke-1 :20
# masukkan nilai mahasiswa ke-2 :30
# masukkan nilai mahasiswa ke-3 :80
# masukkan nilai mahasiswa ke-4 :70
# masukkan nilai mahasiswa ke-5 :6
# masukkan nilai mahasiswa ke-6 :88
# masukkan nilai mahasiswa ke-7 :90
# masukkan nilai mahasiswa ke-8 :58
# masukkan nilai mahasiswa ke-9 :86
# masukkan nilai mahasiswa ke-10 :77

# %%
lulus = 0
tidak_lulus = 0
for n in nilai_mahasiswa:
  if n >= 60:
    lulus += 1
else:
  tidak_lulus += 1

# %%
print("nilai_mahasiswa : ,nilai_mahasiswa")
print("nilai maksimal : ,max(nilai_mahasiswa)")
print("nilai minimal : ,min(nilai_mahasiswa)")
print("rata-rata : ,sum(nilai_mahasiswa)/len(nilai_mahasiswa)")
print("jumlah lulus : ,lulus")
print("jumlah tidak_lulus : ,tidak_lulus")
# Out:
# nilai_mahasiswa : ,nilai_mahasiswa
# nilai maksimal : ,max(nilai_mahasiswa)
# nilai minimal : ,min(nilai_mahasiswa)
# rata-rata : ,sum(nilai_mahasiswa)/len(nilai_mahasiswa)
# jumlah lulus : ,lulus
# jumlah tidak_lulus : ,tidak_lulus

# %%
import matplotlib.pyplot as plt

plt.figure()
kategori = ["Lulus", "Tidak_Lulus"]
data = [lulus, tidak_lulus]

plt.bar(kategori, data)
plt.title("Grafik Data Kelulusan Mahasiswa")
plt.ylabel("Jumlah Mahasiswa")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()
kategori = ["Tertinggi", "Terendah"]
data = [nilai_tertinggi, nilai_terendah]

plt.bar(kategori, data)
plt.title("Grafik Nilai Tertinggi dan Terendah")
plt.ylabel("Nilai")
plt.show()
