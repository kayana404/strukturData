# %% [markdown]
# <a href="https://colab.research.google.com/github/kayana404/strukturData/blob/main/array_n_dimensi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
array_3d = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
print("Array 3D berukuran 2x2x2:")
print(array_3d)
# Out:
# Array 3D berukuran 2x2x2:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
print("Elemen pada indeks [1][0][1]:", array_3d[1, 0, 1])
# Out:
# Elemen pada indeks [1][0][1]: 6

# %%
import numpy as np
total = np.sum(array_3d)
print("Total seluruh elemen array 3D:", total)
# Out:
# Total seluruh elemen array 3D: 36
